# %% [markdown]
# # Making an Interactive Map of MSOE

# %% [markdown]
# ## Initializing The Map

# %%
import folium

# Where map centers
# folium only works with latitude and longitude coordinates
msoe_center = [43.0448, -87.9065]

# Creates the map
msoe_map = folium.Map(location=msoe_center, zoom_start=17)

# %% [markdown]
# ## Adding Markers (2 Different Ways)

# %% [markdown]
# ### Process 1: Manual Addition
# Works for adding a few locations, but gets repetitive for maps requiring multiple markers.

# %%
# each marker is added individually
folium.Marker([43.043, -87.9065], popup="Science Hall").add_to(msoe_map)
folium.Marker([43.0443, -87.907628], popup="Diercks Hall").add_to(msoe_map)
folium.Marker([43.046501, -87.909271], popup="Kern Center").add_to(msoe_map)
folium.Marker([43.043808, -87.907938], popup="Grohmann Museum").add_to(msoe_map)
folium.Marker([43.045319, -87.907707], popup="Viets Tower").add_to(msoe_map)
folium.Marker([43.045513, -87.910464], popup="Grohmann Tower").add_to(msoe_map)
folium.Marker([43.043923, -87.909044], popup="Campus Center").add_to(msoe_map)
folium.Marker([43.044203, -87.906445], popup="Raider Field").add_to(msoe_map)
folium.Marker([43.047713, -87.909264], popup="Viets Field").add_to(msoe_map)
folium.Marker([43.042906, -87.905098], popup="Walter Schroder Library").add_to(msoe_map)
folium.Marker([43.046151, -87.907670], popup="Margaret Loock").add_to(msoe_map)
folium.Marker([43.045552, -87.907659], popup="Mellowes").add_to(msoe_map)
folium.Marker([43.046635, -87.907678], popup="Rosenberg Hall").add_to(msoe_map)
msoe_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a6d7dc736bcb6e14ec821cde5e13e18e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a6d7dc736bcb6e14ec821cde5e13e18e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a6d7dc736bcb6e14ec821cde5e13e18e = L.map(
#                 &quot;map_a6d7dc736bcb6e14ec821cde5e13e18e&quot;,
#                 {
#                     center: [43.0448, -87.9065],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 17,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_64d53c67c14176a029462551481c1969 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_64d53c67c14176a029462551481c1969.addTo(map_a6d7dc736bcb6e14ec821cde5e13e18e);
#
#
#             var marker_be2b617c79a2716e9becfad69ae94841 = L.marker(
#                 [43.043, -87.9065],
#                 {
# }
#             ).addTo(map_a6d7dc736bcb6e14ec821cde5e13e18e);
#
#
#         var popup_bd75fe62d49d85aa033c087c6b382eba = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_99774383a6e5b4991c2a434393fa8674 = $(`&lt;div id=&quot;html_99774383a6e5b4991c2a434393fa8674&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Science Hall&lt;/div&gt;`)[0];
#                 popup_bd75fe62d49d85aa033c087c6b382eba.setContent(html_99774383a6e5b4991c2a434393fa8674);
#
#
#
#         marker_be2b617c79a2716e9becfad69ae94841.bindPopup(popup_bd75fe62d49d85aa033c087c6b382eba)
#         ;
#
#
#
#
#             var marker_98688fdd04e164ed65874f4dc8ca38ec = L.marker(
#                 [43.0443, -87.907628],
#                 {
# }
#             ).addTo(map_a6d7dc736bcb6e14ec821cde5e13e18e);
#
#
#         var popup_3842367edb8e399e2895478b42d4fcda = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_91b5df9f93d8257282aaf9cbbb99de59 = $(`&lt;div id=&quot;html_91b5df9f93d8257282aaf9cbbb99de59&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Diercks Hall&lt;/div&gt;`)[0];
#                 popup_3842367edb8e399e2895478b42d4fcda.setContent(html_91b5df9f93d8257282aaf9cbbb99de59);
#
#
#
#         marker_98688fdd04e164ed65874f4dc8ca38ec.bindPopup(popup_3842367edb8e399e2895478b42d4fcda)
#         ;
#
#
#
#
#             var marker_7f8b170c5d4d2260053a617ec6870035 = L.marker(
#                 [43.046501, -87.909271],
#                 {
# }
#             ).addTo(map_a6d7dc736bcb6e14ec821cde5e13e18e);
#
#
#         var popup_2dd269fbabdb9af6bb4863fcfcd81f1b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1a068b34b91f0589fe6baf4a2197e839 = $(`&lt;div id=&quot;html_1a068b34b91f0589fe6baf4a2197e839&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Kern Center&lt;/div&gt;`)[0];
#                 popup_2dd269fbabdb9af6bb4863fcfcd81f1b.setContent(html_1a068b34b91f0589fe6baf4a2197e839);
#
#
#
#         marker_7f8b170c5d4d2260053a617ec6870035.bindPopup(popup_2dd269fbabdb9af6bb4863fcfcd81f1b)
#         ;
#
#
#
#
#             var marker_8805b5eefeaf60e8b0be5cc967629740 = L.marker(
#                 [43.043808, -87.907938],
#                 {
# }
#             ).addTo(map_a6d7dc736bcb6e14ec821cde5e13e18e);
#
#
#         var popup_a1519bf6d2e7bf694683cd0e98ad341d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b51c4e74bd2a353c849f683108287cba = $(`&lt;div id=&quot;html_b51c4e74bd2a353c849f683108287cba&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Grohmann Museum&lt;/div&gt;`)[0];
#                 popup_a1519bf6d2e7bf694683cd0e98ad341d.setContent(html_b51c4e74bd2a353c849f683108287cba);
#
#
#
#         marker_8805b5eefeaf60e8b0be5cc967629740.bindPopup(popup_a1519bf6d2e7bf694683cd0e98ad341d)
#         ;
#
#
#
#
#             var marker_07a4059f3f63079124c33bb5fd965ee1 = L.marker(
#                 [43.045319, -87.907707],
#                 {
# }
#             ).addTo(map_a6d7dc736bcb6e14ec821cde5e13e18e);
#
#
#         var popup_5516404db3d5fe274afd48bf45d936e7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fd245931ee3616e460c25e483719fd67 = $(`&lt;div id=&quot;html_fd245931ee3616e460c25e483719fd67&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Viets Tower&lt;/div&gt;`)[0];
#                 popup_5516404db3d5fe274afd48bf45d936e7.setContent(html_fd245931ee3616e460c25e483719fd67);
#
#
#
#         marker_07a4059f3f

# %% [markdown]
# ### Process 2: Loop Addition
# Don't need to rely on individually adding every marker.

# %%
# list of tuples with the necessary information
locations = [
    ("Science Hall", 43.043, -87.9065),
    ("Diercks Hall", 43.0443, -87.907628),
    ("Kern Center", 43.046501, -87.909271),
    ("Grohmann Museum", 43.043808, -87.907938),
    ("Viets Tower", 43.045319, -87.907707),
    ("Grohmann Tower", 43.045513, -87.910464),
    ("Campus Center", 43.043923, -87.909044),
    ("Raider Field", 43.044203, -87.906445),
    ("Viets Field", 43.047713, -87.909264),
    ("Walter Schroder Library", 43.042906,-87.905098),
    ("Margaret Loock", 43.046151, -87.907670),
    ("Mellowes", 43.045552, -87.907659),
    ("Rosenberg Hall", 43.046635, -87.907678)
]
# loop iterates through the indexes of the tuples
for area in locations:
    folium.Marker(
        location=[area[1], area[2]],
        popup = area[0]
).add_to(msoe_map)
msoe_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a6d7dc736bcb6e14ec821cde5e13e18e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a6d7dc736bcb6e14ec821cde5e13e18e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a6d7dc736bcb6e14ec821cde5e13e18e = L.map(
#                 &quot;map_a6d7dc736bcb6e14ec821cde5e13e18e&quot;,
#                 {
#                     center: [43.0448, -87.9065],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 17,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_64d53c67c14176a029462551481c1969 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_64d53c67c14176a029462551481c1969.addTo(map_a6d7dc736bcb6e14ec821cde5e13e18e);
#
#
#             var marker_be2b617c79a2716e9becfad69ae94841 = L.marker(
#                 [43.043, -87.9065],
#                 {
# }
#             ).addTo(map_a6d7dc736bcb6e14ec821cde5e13e18e);
#
#
#         var popup_bd75fe62d49d85aa033c087c6b382eba = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_99774383a6e5b4991c2a434393fa8674 = $(`&lt;div id=&quot;html_99774383a6e5b4991c2a434393fa8674&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Science Hall&lt;/div&gt;`)[0];
#                 popup_bd75fe62d49d85aa033c087c6b382eba.setContent(html_99774383a6e5b4991c2a434393fa8674);
#
#
#
#         marker_be2b617c79a2716e9becfad69ae94841.bindPopup(popup_bd75fe62d49d85aa033c087c6b382eba)
#         ;
#
#
#
#
#             var marker_98688fdd04e164ed65874f4dc8ca38ec = L.marker(
#                 [43.0443, -87.907628],
#                 {
# }
#             ).addTo(map_a6d7dc736bcb6e14ec821cde5e13e18e);
#
#
#         var popup_3842367edb8e399e2895478b42d4fcda = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_91b5df9f93d8257282aaf9cbbb99de59 = $(`&lt;div id=&quot;html_91b5df9f93d8257282aaf9cbbb99de59&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Diercks Hall&lt;/div&gt;`)[0];
#                 popup_3842367edb8e399e2895478b42d4fcda.setContent(html_91b5df9f93d8257282aaf9cbbb99de59);
#
#
#
#         marker_98688fdd04e164ed65874f4dc8ca38ec.bindPopup(popup_3842367edb8e399e2895478b42d4fcda)
#         ;
#
#
#
#
#             var marker_7f8b170c5d4d2260053a617ec6870035 = L.marker(
#                 [43.046501, -87.909271],
#                 {
# }
#             ).addTo(map_a6d7dc736bcb6e14ec821cde5e13e18e);
#
#
#         var popup_2dd269fbabdb9af6bb4863fcfcd81f1b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1a068b34b91f0589fe6baf4a2197e839 = $(`&lt;div id=&quot;html_1a068b34b91f0589fe6baf4a2197e839&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Kern Center&lt;/div&gt;`)[0];
#                 popup_2dd269fbabdb9af6bb4863fcfcd81f1b.setContent(html_1a068b34b91f0589fe6baf4a2197e839);
#
#
#
#         marker_7f8b170c5d4d2260053a617ec6870035.bindPopup(popup_2dd269fbabdb9af6bb4863fcfcd81f1b)
#         ;
#
#
#
#
#             var marker_8805b5eefeaf60e8b0be5cc967629740 = L.marker(
#                 [43.043808, -87.907938],
#                 {
# }
#             ).addTo(map_a6d7dc736bcb6e14ec821cde5e13e18e);
#
#
#         var popup_a1519bf6d2e7bf694683cd0e98ad341d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b51c4e74bd2a353c849f683108287cba = $(`&lt;div id=&quot;html_b51c4e74bd2a353c849f683108287cba&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Grohmann Museum&lt;/div&gt;`)[0];
#                 popup_a1519bf6d2e7bf694683cd0e98ad341d.setContent(html_b51c4e74bd2a353c849f683108287cba);
#
#
#
#         marker_8805b5eefeaf60e8b0be5cc967629740.bindPopup(popup_a1519bf6d2e7bf694683cd0e98ad341d)
#         ;
#
#
#
#
#             var marker_07a4059f3f63079124c33bb5fd965ee1 = L.marker(
#                 [43.045319, -87.907707],
#                 {
# }
#             ).addTo(map_a6d7dc736bcb6e14ec821cde5e13e18e);
#
#
#         var popup_5516404db3d5fe274afd48bf45d936e7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fd245931ee3616e460c25e483719fd67 = $(`&lt;div id=&quot;html_fd245931ee3616e460c25e483719fd67&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Viets Tower&lt;/div&gt;`)[0];
#                 popup_5516404db3d5fe274afd48bf45d936e7.setContent(html_fd245931ee3616e460c25e483719fd67);
#
#
#
#         marker_07a4059f3f

# %% [markdown]
# ## Map Customization

# %%
# Folium sometimes generates previous edits from memory, helpful to re-initialize the map
msoe_map2 = folium.Map(location=msoe_center, zoom_start=17)
# a 4th 'type' entry in the tuple list has been added
locations_custom = [
    ("Science Hall", 43.043, -87.9065,'Class'),
    ("Diercks Hall", 43.0443, -87.907628,'Class'),
    ("Kern Center", 43.046501, -87.909271,'Sports'),
    ("Grohmann Museum", 43.043808, -87.907938,'Class'),
    ("Viets Tower", 43.045319, -87.907707,'Student Life'),
    ("Grohmann Tower", 43.045513, -87.910464,'Student Life'),
    ("Campus Center", 43.043923, -87.909044,'Student Life'),
    ("Raider Field", 43.044203, -87.906445,'Sports'),
    ("Viets Field", 43.047713, -87.909264, 'Sports'),
    ("Walter Schroder Library", 43.042906,-87.905098,'Class'),
    ("Margaret Loock", 43.046151, -87.907670,'Student Life'),
    ("Mellowes", 43.045552, -87.907659,'Student Life'),
    ("Rosenberg Hall", 43.046635, -87.907678,'Class')
]
# determines what the marker should look like based on type
for loc in locations_custom:
    if 'Class' in loc[3]:
        mark_color = 'red'
        mark = 'book'
    elif 'Sports' in loc[3]:
        mark_color = 'green'
        mark = 'star'
    elif 'Student Life' in loc[3]:
        mark_color = 'blue'
        mark = 'home'
# adds the markers into the map
    folium.Marker(
        location = [loc[1],loc[2]],
        tooltip = loc[0],
        icon = folium.Icon(color = mark_color, icon = mark)).add_to(msoe_map2)
# Defines the desired boundary
campus_boundary = [
    [43.0485, -87.9110], 
    [43.0485, -87.9045], 
    [43.0425, -87.9045], 
    [43.0425, -87.9110] 
]
# .Polygon draws a line from point-to-point
folium.Polygon(
    locations=campus_boundary,
    color="blue",  
    fill = False,
    popup="MSOE Campus"
).add_to(msoe_map2)
msoe_map2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_20d187f773fe7bd1ee8d3553605b6e57 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_20d187f773fe7bd1ee8d3553605b6e57&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_20d187f773fe7bd1ee8d3553605b6e57 = L.map(
#                 &quot;map_20d187f773fe7bd1ee8d3553605b6e57&quot;,
#                 {
#                     center: [43.0448, -87.9065],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 17,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7eb78f851934a1dd4cfe83eac8cefa6e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7eb78f851934a1dd4cfe83eac8cefa6e.addTo(map_20d187f773fe7bd1ee8d3553605b6e57);
#
#
#             var marker_c98bf6c572a78ffa40f0b02847c41ae6 = L.marker(
#                 [43.043, -87.9065],
#                 {
# }
#             ).addTo(map_20d187f773fe7bd1ee8d3553605b6e57);
#
#
#             var icon_d4950cc7102f36e98d722c2a24efc065 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;book&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#             marker_c98bf6c572a78ffa40f0b02847c41ae6.bindTooltip(
#                 `&lt;div&gt;
#                      Science Hall
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_c98bf6c572a78ffa40f0b02847c41ae6.setIcon(icon_d4950cc7102f36e98d722c2a24efc065);
#
#
#             var marker_ba5b8e5853f8a53683e9a3ca4f492063 = L.marker(
#                 [43.0443, -87.907628],
#                 {
# }
#             ).addTo(map_20d187f773fe7bd1ee8d3553605b6e57);
#
#
#             var icon_894931213952fbe08c4b29c66c34c02c = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;book&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#             marker_ba5b8e5853f8a53683e9a3ca4f492063.bindTooltip(
#                 `&lt;div&gt;
#                      Diercks Hall
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_ba5b8e5853f8a53683e9a3ca4f492063.setIcon(icon_894931213952fbe08c4b29c66c34c02c);
#
#
#             var marker_b46590840ee2446ff6d6a929933277be = L.marker(
#                 [43.046501, -87.909271],
#                 {
# }
#             ).addTo(map_20d187f773fe7bd1ee8d3553605b6e57);
#
#
#             var icon_db56f21e35e0e4c316b29d41af41c1d0 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;star&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#             marker_b46590840ee2446ff6d6a929933277be.bindTooltip(
#                 `&lt;div&gt;
#                      Kern Center
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_b46590840ee2446ff6d6a929933277be.setIcon(icon_db56f21e35e0e4c316b29d41af41c1d0);
#
#
#             var marker_5fb4cea73e5976792a92e15192ea2d41 = L.marker(
#                 [43.043808, -87.907938],
#                 {
# }
#             ).addTo(map_20d187f773fe7bd1ee8d3553605b6e57);
#
#
#             var icon_3b2c91af035251d1d8c0ce57a599ab71 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;book&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#             marker_5fb4cea73e5976792a92e15192ea2d41.bindTooltip(
#                 `&lt;div&gt;
#                      Grohmann Museum
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_5fb4cea73e5976792a92e15192ea2d41.setIcon(icon_3b2c91af035251d1d8c0ce57a599ab71);
#
#
#             var marker_88ed730f3aede91c224c77a80e6befdd = L.marker(
#                 [43.045319, -87.907707],
#                 {
# }
#             ).addTo(map_20d187f773fe7bd1ee8d3553605b6e57);
#
#
#             var icon_641f7ad26

# %% [markdown]
# ## Saving The Map
# Allows you to access the map as an html file

# %%
msoe_map.save('Campus_map.html')
